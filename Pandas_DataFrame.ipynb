# %% [markdown]
# <a href="https://colab.research.google.com/github/mariuszDolinski/Data-Science-Course/blob/main/Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.DataFrame(data=[12,23,34])
df
# Out:
#     0
# 0  12
# 1  23
# 2  34
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1[0].plot(kind='hist', bins=20, title=0)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
# ...

# %%
df = pd.DataFrame(data=[12,23,34], index=['first', 'second', 'thitd'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     23
# thitd      34

# %%
df = pd.DataFrame(data={'WIG20': ['ORLEN', 'PKO BP'],
                        'mWIG40': ['Amica', 'Playway']})
df
# Out:
#     WIG20   mWIG40
# 0   ORLEN    Amica
# 1  PKO BP  Playway

# %%
df = pd.DataFrame(data=[[12,23,34], [121,24,3]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      12     23     34
# second    121     24      3

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.values
# Out:
# array([[12, 23, 34],
#        [12, 23, 34]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
df.describe()
# Out:
#        col_1  col_2  col_3
# count    2.0    2.0    2.0
# mean    12.0   23.0   34.0
# std      0.0    0.0    0.0
# min     12.0   23.0   34.0
# 25%     12.0   23.0   34.0
# 50%     12.0   23.0   34.0
# 75%     12.0   23.0   34.0
# max     12.0   23.0   34.0

# %%
df.describe().T
# Out:
#        count  mean        std   min    25%   50%    75%    max
# col_1    2.0  66.5  77.074639  12.0  39.25  66.5  93.75  121.0
# col_2    2.0  23.5   0.707107  23.0  23.25  23.5  23.75   24.0
# col_3    2.0  18.5  21.920310   3.0  10.75  18.5  26.25   34.0

# %%
df['col_1']
# Out:
# first      12
# second    121
# Name: col_1, dtype: int64

# %%
type(df['col_1'])
# Out:
# pandas.core.series.Series

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ['a', 'b', 'c']
df
# Out:
#           a   b   c
# first    12  23  34
# second  121  24   3

# %%
df.a
# Out:
# first      12
# second    121
# Name: a, dtype: int64

# %%
df['d'] = df.a + df.c
df
# Out:
#           a   b   c    d
# first    12  23  34   46
# second  121  24   3  124

# %%
df = pd.DataFrame(data=[[12,23,34], [121,24,3]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      12     23     34
# second    121     24      3

# %%
df.loc['first']
# Out:
# col_1    12
# col_2    23
# col_3    34
# Name: first, dtype: int64

# %%
df.iloc[0]
# Out:
# col_1    12
# col_2    23
# col_3    34
# Name: first, dtype: int64

# %%
df.loc['first', 'col_2']
# Out:
# 23

# %%
df.loc[:, 'col_2']
# Out:
# first     23
# second    24
# Name: col_2, dtype: int64

# %%
df.iloc[0,1]
# Out:
# 23
